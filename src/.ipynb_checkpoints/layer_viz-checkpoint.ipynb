# %%
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from pylab import *

# %%
neurons = []
z = 0

xs = []
ys = []
zs = []

for i in range(32):
    for j in range(32):
        xs.append(i)
        ys.append(j)
        zs.append(z)

# %%
# fake layer data
time = 10
layer = np.random.randn(10,32,32)

nucleus = layer[0].flatten().tolist()

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.set_aspect('equal')
ax.get_xaxis().set_visible(False)
ax.get_yaxis().set_visible(False)

im = ax.imshow(np.random.rand(300,300),cmap='gray',interpolation='nearest')
im.set_clim([0,1])
fig.set_size_inches([5,5])


matplotlib.tight_layout()


def update_img(n):
    tmp = rand(300,300)
    im.set_data(tmp)
    return im

#legend(loc=0)
ani = animation.FuncAnimation(fig,update_img,300,interval=30)
writer = animation.writers['ffmpeg'](fps=30)

ani.save('demo.mp4',writer=writer,dpi=dpi)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-30-c58b5fa9bf9a> in <module>()
#      10
#      11
# ---> 12 tight_layout()
#      13
#      14
#
# NameError: name 'tight_layout' is not defined
